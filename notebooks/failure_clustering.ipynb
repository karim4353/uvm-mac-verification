# %% [markdown]
# # Failure Clustering Notebook
# This notebook demonstrates parsing → feature extraction → clustering.

# %%
import pandas as pd
print('Notebook runs in CI in fast mode (if sample logs exist)')
